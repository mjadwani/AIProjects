# %%
import pandas as pd

# %%
df1 = pd.read_csv("zparmlist_DMU1DB2A.csv")
df2 = pd.read_csv("zparmlist_DNK3.csv")

# %%
# df.head()

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'zparm_value', 'macro_name'], dtype='object')

# %%
# import pandas as pd

# # Load the files
# df1 = pd.read_csv('file1.csv')
# df2 = pd.read_csv('file2.csv')

# Optional: Set an index if there is a unique ID (e.g., 'EMPLOYEE_ID')
# df1.set_index('ID', inplace=True)
# df2.set_index('ID', inplace=True)

# Find differences
diff = df1['zparm_value'].compare(df2['zparm_value'])

# Save the differences to a new file
# diff.to_csv('differences_report.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 12
#       1 # import pandas as pd
#       2
#       3 # # Load the files
#    (...)     10
#      11 # Find differences
# ---> 12 diff = df1['zparm_value'].compare(df2['zparm_value'])
#      14 # Save the differences to a new file
#      15 # diff.to_csv('differences_report.csv')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:3378, in Series.compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    3304 @doc(
#    3305     _shared_docs["compare"],
#    3306     dedent(
#    (...)   3376     result_names: Suffixes = ("self", "other"),
#    3377 ) -> DataFrame | Series:
# -> 3378     return super().compare(
#    3379         other=other,
#    3380         align_axis=align_axis,
#    3381         keep_shape=keep_shape,
#    3382         keep_equal=keep_equal,
# ...
